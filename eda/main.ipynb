# %% [markdown]
# # EDA Combined preprocessed dataset

# %%
import pandas as pd

# %%
COMBINED_PREPROCESSED_DATASET_PATH = "../datasets/preprocessed/combined_dataset.json"
combined_dataset = pd.read_json(COMBINED_PREPROCESSED_DATASET_PATH)
combined_dataset
# Out:
#                                              RouteID station_code  \
# 0       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8
# 1       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8
# 2       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8
# 3       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8
# 4       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8
# ...                                              ...          ...
# 714564  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee         DLA7
# 714565  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee         DLA7
# 714566  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee         DLA7
# 714567  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee         DLA7
# 714568  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee         DLA7
#
#        date_YYYY_MM_DD departure_time_utc  executor_capacity_cm3  Zone  \
# 0           2018-06-17           17:23:00             3539605.75  K-21
# 1           2018-06-17           17:23:00             3539605.75  K-21
# 2           2018-06-17           17:23:00             3539605.75  K-21
# 3           2018-06-17           17:23:00             3539605.75  K-21
# 4           2018-06-17           17:23:00             3539605.75  K-21
# ...                ...                ...                    ...   ...
# 714564      2018-07-08           15:42:06             3539605.75  G-18
# 714565      2018-07-08           15:42:06             3539605.75  G-18
# 714566      2018-07-08           15:42:06             3539605.75  G-18
# 714567      2018-07-08           15:42:06             3539605.75  G-18
# 714568      2018-07-08           15:42:06             3539605.75  G-18
#
#        starting_point StopID                                       PackageID  \
# 0                  UZ     AH  PackageID_fd17bd67-a3d8-45b9-936b-c7e9d879102e
# 1                  UZ     AH  PackageID_f78261e7-4c8c-4d72-b007-9934a53a700b
# 2                  UZ     AJ  PackageID_a8e394ee-4208-412d-8b34-8cbce880a322
# 3                  UZ     AL  PackageID_b7c39ed4-fa0a-497a-ae0c-e3515734f8ae
# 4                  UZ     AL  PackageID_e980c24b-ab88-4af1-b3f9-1f851823f561
# ...               ...    ...                                             ...
# 714564             XL     YU  PackageID_b0bad72b-041e-4b5b-8303-03131c837b8d
# 714565             XL     YU  PackageID_b2c6f0de-6fcf-4616-b2cd-ba63ef6d0715
# 714566             XL     YU  PackageID_3de4b3fd-d80d-4ae7-a519-c82a4e46c48c
# 714567             XL     ZQ  PackageID_59aae7fe-cbb2-47c8-8c2f-59a97154ccd9
# 714568             XL     ZS  PackageID_267d089c-6c82-49b0-80f8-6748db36c8dc
#
#         planned_service_time_seconds  ...  weight_cm  time_to_arrive  \
# 0                               31.5  ...       30.5           703.9
# 1                               31.5  ...       17.8           703.9
# 2                               40.0  ...       17.8           670.6
# 3                               47.0  ...       21.8           789.6
# 4                               47.0  ...       35.6           789.6
# ...                              ...  ...        ...             ...
# 714564                          38.3  ...       40.6          2386.8
# 714565                          38.3  ...       41.3          2386.8
# 714566                          38.3  ...       36.8          2386.8
# 714567                         102.0  ...       33.0          2568.5
# 714568                          74.0  ...       13.7          2588.5
#
#         day_of_week  month   StartLat    StartLon    StopLat     StopLon  \
# 0            Sunday      6  33.918699 -118.324843  33.885480 -118.344553
# 1            Sunday      6  33.918699 -118.324843  33.885480 -118.344553
# 2            Sunday      6  33.918699 -118.324843  33.902808 -118.355223
# 3            Sunday      6  33.918699 -118.324843  33.893616 -118.358108
# 4            Sunday      6  33.918699 -118.324843  33.893616 -118.358108
# ...             ...    ...        ...         ...        ...         ...
# 714564       Sunday      7  33.965477 -117.653303  34.152862 -117.502335
# 714565       Sunday      7  33.965477 -117.653303  34.152862 -117.502335
# 714566       Sunday      7  33.965477 -117.653303  34.152862 -117.502335
# 714567       Sunday      7  33.965477 -117.653303  34.155712 -117.528523
# 714568       Sunday      7  33.965477 -117.653303  34.161928 -117.508143
#
#         distance_lat  distance_lon
# 0           0.033219      0.019710
# 1           0.033219      0.019710
# 2           0.015891      0.030380
# 3           0.025083      0.033265
# 4           0.025083      0.033265
# ...              ...           ...
# 714564      0.187385      0.150968
# 714565      0.187385      0.150968
# 714566      0.187385      0.150968
# 714567      0.190235      0.124780
# 714568      0.196451      0.145160
#
# [714569 rows x 22 columns]

# %%
combined_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714569 entries, 0 to 714568
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   RouteID                        714569 non-null  object
#  1   station_code                   714569 non-null  object
#  2   date_YYYY_MM_DD                714569 non-null  object
#  3   departure_time_utc             714569 non-null  object
#  4   executor_capacity_cm3          714569 non-null  float64
#  5   Zone                           714569 non-null  object
#  6   starting_point                 714569 non-null  object
#  7   StopID                         714569 non-null  object
#  8   PackageID                      714569 non-null  object
#  9   planned_service_time_seconds   714569 non-null  float64
#  10  depth_cm                       714569 non-null  float64
#  11  height_cm                      714569 non-null  float64
#  12  weight_cm                      714569 non-null  float64
#  13  time_to_arrive                 714569 non-null  float64
#  14  day_of_week                    714569 non-null  object
#  15  month                          714569 non-null  int64
#  16  StartLat                       714569 non-null  float64
#  17  StartLon                       714569 non-null  float64
#  18  StopLat                        714569 non-null  float64
#  19  StopLon                        714569 non-null  float64
#  20  distance_lat                   714569 non-null  float64
#  21  distance_lon                   714569 non-null  float64
#  22  executor_capacity_cm3_discret  714569 non-null  category
# dtypes: category(1), float64(12), int64(1), object(9)
# memory usage: 120.6+ MB

# %%
missing_count = combined_dataset.isnull().sum()
missing_percentage = missing_count / combined_dataset.shape[0] * 100

# Sort the missing_percentage in descending order
missing_percentage = missing_percentage.sort_values(ascending=False)
# Sort the missing_count in descending order
missing_count = missing_count[missing_percentage.index]

# Print the results
print("Missing values count:\n", missing_count)
print("Missing percentage:\n", missing_percentage)
# Out:
# Missing values count:
#  RouteID                          0
# weight_cm                        0
# distance_lon                     0
# distance_lat                     0
# StopLon                          0
# StopLat                          0
# StartLon                         0
# StartLat                         0
# month                            0
# day_of_week                      0
# time_to_arrive                   0
# height_cm                        0
# station_code                     0
# depth_cm                         0
# planned_service_time_seconds     0
# PackageID                        0
# StopID                           0
# starting_point                   0
# Zone                             0
# executor_capacity_cm3            0
# departure_time_utc               0
# date_YYYY_MM_DD                  0
# executor_capacity_cm3_discret    0
# dtype: int64
# Missing percentage:
#  RouteID                          0.0
# weight_cm                        0.0
# distance_lon                     0.0
# distance_lat                     0.0
# StopLon                          0.0
# StopLat                          0.0
# StartLon                         0.0
# StartLat                         0.0
# month                            0.0
# day_of_week                      0.0
# time_to_arrive                   0.0
# height_cm                        0.0
# station_code                     0.0
# depth_cm                         0.0
# planned_service_time_seconds     0.0
# PackageID                        0.0
# StopID                           0.0
# starting_point                   0.0
# Zone                             0.0
# executor_capacity_cm3            0.0
# departure_time_utc               0.0
# date_YYYY_MM_DD                  0.0
# executor_capacity_cm3_discret    0.0
# dtype: float64

# %% [markdown]
# ## Numerical Variables

# %%
numerical = [x for x in list(combined_dataset.columns) if (pd.api.types.is_float_dtype(combined_dataset[x]))]
print(numerical)
# Out:
# ['executor_capacity_cm3', 'planned_service_time_seconds', 'depth_cm', 'height_cm', 'weight_cm', 'time_to_arrive', 'StartLat', 'StartLon', 'StopLat', 'StopLon', 'distance_lat', 'distance_lon']

# %%
combined_dataset.describe()
# Out:
#        executor_capacity_cm3  planned_service_time_seconds       depth_cm  \
# count           7.145690e+05                 714569.000000  714569.000000
# mean            3.668698e+06                     70.413758      33.795002
# std             4.835055e+05                     69.740068       9.199817
# min             3.114853e+06                      1.000000       0.300000
# 25%             3.313071e+06                     37.500000      25.700000
# 50%             3.539606e+06                     54.300000      32.300000
# 75%             4.247527e+06                     81.000000      38.600000
# max             4.672280e+06                   7325.000000     134.600000
#
#            height_cm      weight_cm  time_to_arrive          month  \
# count  714569.000000  714569.000000   714569.000000  714569.000000
# mean       10.158491      24.548767     1832.104515       7.649726
# std         7.339519       7.334135      612.804355       1.336050
# min         0.000000       0.300000       45.900000       6.000000
# 25%         4.800000      17.800000     1367.400000       6.000000
# 50%         7.600000      24.100000     1816.300000       7.000000
# 75%        12.700000      29.200000     2227.400000       9.000000
# max        73.700000      95.300000     7179.700000      10.000000
#
#             StartLat       StartLon        StopLat        StopLon  \
# count  714569.000000  714569.000000  714569.000000  714569.000000
# mean       38.008457    -106.649243      37.993920    -106.653152
# std         5.347457      18.042316       5.337329      18.046383
# min        30.445236    -122.328049      30.120233    -122.574461
# 25%        33.918699    -118.324843      33.821785    -118.373705
# 50%        34.007369    -117.847178      34.124600    -117.739173
# 75%        42.139891     -88.097259      42.212239     -88.112885
# max        47.937344     -71.055555      48.072868     -70.831936
#
#         distance_lat   distance_lon
# count  714569.000000  714569.000000
# mean        0.108070       0.120189
# std         0.076192       0.086002
# min         0.000001       0.000003
# 25%         0.053554       0.050089
# 50%         0.091125       0.104569
# 75%         0.146190       0.175669
# max         0.482494       0.513682

# %%
from matplotlib import pyplot as plt
import seaborn as sns
fig, ax1=plt.subplots(1,3)
ax2 = ax1.ravel()
fig.set_figheight(4)
fig.set_figwidth(15)
plt.subplots_adjust(hspace=0.3)
sns.histplot(combined_dataset['executor_capacity_cm3'], kde=True, ax=ax2[0],stat='percent',bins=10)
sns.histplot(combined_dataset['executor_capacity_cm3'], kde=True, ax=ax2[1],stat='percent', bins=5)
sns.histplot(combined_dataset['executor_capacity_cm3'], kde=True, ax=ax2[2],stat='percent', bins=3)
# Out:
# c:\Users\tatys\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\tatys\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\tatys\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\tatys\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\tatys\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\tatys\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='executor_capacity_cm3', ylabel='Percent'>

# %%
limits = [0*10**6,4*10**6,4.5*10**6,5*10**6]
category_executor = ['<4','<4 <4.5', '>4.5']
combined_dataset['executor_capacity_cm3_discret'] = pd.cut(combined_dataset['executor_capacity_cm3'], bins=limits, labels=category_executor)

# %%
combined_dataset.head()
# Out:
#                                         RouteID station_code date_YYYY_MM_DD  \
# 0  RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8      2018-06-17
# 1  RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8      2018-06-17
# 2  RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8      2018-06-17
# 3  RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8      2018-06-17
# 4  RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8      2018-06-17
#
#   departure_time_utc  executor_capacity_cm3  Zone starting_point StopID  \
# 0           17:23:00             3539605.75  K-21             UZ     AH
# 1           17:23:00             3539605.75  K-21             UZ     AH
# 2           17:23:00             3539605.75  K-21             UZ     AJ
# 3           17:23:00             3539605.75  K-21             UZ     AL
# 4           17:23:00             3539605.75  K-21             UZ     AL
#
#                                         PackageID  \
# 0  PackageID_fd17bd67-a3d8-45b9-936b-c7e9d879102e
# 1  PackageID_f78261e7-4c8c-4d72-b007-9934a53a700b
# 2  PackageID_a8e394ee-4208-412d-8b34-8cbce880a322
# 3  PackageID_b7c39ed4-fa0a-497a-ae0c-e3515734f8ae
# 4  PackageID_e980c24b-ab88-4af1-b3f9-1f851823f561
#
#    planned_service_time_seconds  ...  time_to_arrive  day_of_week  month  \
# 0                          31.5  ...           703.9       Sunday      6
# 1                          31.5  ...           703.9       Sunday      6
# 2                          40.0  ...           670.6       Sunday      6
# 3                          47.0  ...           789.6       Sunday      6
# 4                          47.0  ...           789.6       Sunday      6
#
#     StartLat    StartLon    StopLat     StopLon  distance_lat  distance_lon  \
# 0  33.918699 -118.324843  33.885480 -118.344553      0.033219      0.019710
# 1  33.918699 -118.324843  33.885480 -118.344553      0.033219      0.019710
# 2  33.918699 -118.324843  33.902808 -118.355223      0.015891      0.030380
# 3  33.918699 -118.324843  33.893616 -118.358108      0.025083      0.033265
# 4  33.918699 -118.324843  33.893616 -118.358108      0.025083      0.033265
#
#    executor_capacity_cm3_discret
# 0                             <4
# 1                             <4
# 2                             <4
# 3                             <4
# 4                             <4
#
# [5 rows x 23 columns]

# %%
combined_dataset_colums = combined_dataset.columns.tolist()
no_discrete = combined_dataset_colums.copy()

no_discrete.pop()
print(no_discrete)
# Out:
# ['RouteID', 'station_code', 'date_YYYY_MM_DD', 'departure_time_utc', 'executor_capacity_cm3', 'Zone', 'starting_point', 'StopID', 'PackageID', 'planned_service_time_seconds', 'depth_cm', 'height_cm', 'weight_cm', 'time_to_arrive', 'day_of_week', 'month', 'StartLat', 'StartLon', 'StopLat', 'StopLon', 'distance_lat', 'distance_lon']

# %%
#pd.crosstab(combined_dataset['executor_capacity_cm3_discret'], combined_dataset['Zone'], combined_dataset['starting_point'], margins=True, margins_name='Total', aggfunc= ',')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\tatys\Documents\Proyecto\data-mining-2023-II\eda\main.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tatys/Documents/Proyecto/data-mining-2023-II/eda/main.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> pd.crosstab(combined_dataset['executor_capacity_cm3_discret'], combined_dataset['Zone'], combined_dataset['starting_point'], margins=True, margins_name='Total', aggfunc= ',')
#
# File c:\Users\tatys\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:711, in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     707     kwargs = {"aggfunc": aggfunc}
#     709 # error: Argument 7 to "pivot_table" of "DataFrame" has incompatible type
#     710 # "**Dict[str, object]"; expected "Union[...]"
# --> 711 table = df.pivot_table(
#     712     "__dummy__",
#     713     index=unique_rownames,
#     714     columns=unique_colnames,
#     715     margins=margins,
#     716     margins_name=margins_name,
#     717     dropna=dropna,
#     718     **kwargs,  # type: ignore[arg-type]
#     719 )
#     721 # Post-process
#     722 if normalize is not False:
#
# File c:\Users\tatys\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:9193, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9176 @Substitution("")
#    9177 @Appender(_shared_docs["pivot_table"])
#    9178 def pivot_table(
#    (...)
#    9189     sort: bool = True,
#    9190 ) -> DataFrame:
#    9191     from pandas.core.reshape.pivot import pivot_table
# -> 9193     return pivot_table(
#    9194         self,
#    9195         values=values,
#    9196         index=index,
#    9197         columns=columns,
#    9198         aggfunc=aggfunc,
#    9199         fill_value=fill_value,
#    9200         margins=margins,
#    9201         dropna=dropna,
#    9202         margins_name=margins_name,
#    9203         observed=observed,
#    9204         sort=sort,
#    9205     )
#
# File c:\Users\tatys\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:99, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      96     table = concat(pieces, keys=keys, axis=1)
#      97     return table.__finalize__(data, method="pivot_table")
# ---> 99 table = __internal_pivot_table(
#     100     data,
#     101     values,
#     102     index,
#     103     columns,
#     104     aggfunc,
#     105     fill_value,
#     106     margins,
#     107     dropna,
#     108     margins_name,
#     109     observed,
#     110     sort,
#     111 )
#     112 return table.__finalize__(data, method="pivot_table")
#
# File c:\Users\tatys\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:169, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     166     values = list(values)
#     168 grouped = data.groupby(keys, observed=observed, sort=sort, dropna=dropna)
# --> 169 agged = grouped.agg(aggfunc)
#     171 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     172     agged = agged.dropna(how="all")
#
# File c:\Users\tatys\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:1442, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1439     kwargs["engine_kwargs"] = engine_kwargs
#    1441 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1442 result = op.agg()
#    1443 if not is_dict_like(func) and result is not None:
#    1444     # GH #52849
#    1445     if not self.as_index and is_list_like(func):
#
# File c:\Users\tatys\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:172, in Apply.agg(self)
#     169 kwargs = self.kwargs
#     171 if isinstance(func, str):
# --> 172     return self.apply_str()
#     174 if is_dict_like(func):
#     175     return self.agg_dict_like()
#
# File c:\Users\tatys\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:586, in Apply.apply_str(self)
#     584         else:
#     585             self.kwargs["axis"] = self.axis
# --> 586 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File c:\Users\tatys\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:682, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     680 else:
#     681     msg = f"'{func}' is not a valid function for '{type(obj).__name__}' object"
# --> 682     raise AttributeError(msg)
#
# AttributeError: ',' is not a valid function for 'DataFrameGroupBy' object

# %% [markdown]
# ## Categorical Variables

# %%
categorical = [x for x in list(combined_dataset.columns) if (x not in numerical)]
print(categorical)
# Out:
# ['RouteID', 'station_code', 'date_YYYY_MM_DD', 'departure_time_utc', 'Zone', 'starting_point', 'StopID', 'PackageID', 'day_of_week', 'month', 'executor_capacity_cm3_discret']

# %%
combined_dataset_categorical = combined_dataset.columns.tolist()

# %%
for c in combined_dataset_categorical:
  print(c)
  print(combined_dataset[c].unique())
  print(combined_dataset[c].nunique())
  print('\n')
# Out:
# RouteID
# ['RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e'
#  'RouteID_00337a3a-19c6-4821-9350-ad3cf0532047'
#  'RouteID_0034b931-97a7-485f-a6b3-b22798489094' ...
#  'RouteID_fedf4c2f-2618-4598-bfb5-ec90822c9a29'
#  'RouteID_ff30c100-6266-461d-9c56-939775a1defe'
#  'RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee']
# 3007
#
#
# station_code
# ['DLA8' 'DLA4' 'DSE4' 'DLA3' 'DLA9' 'DAU1' 'DLA7' 'DCH4' 'DBO3' 'DSE2'
#  'DCH3' 'DCH1' 'DCH2' 'DLA5' 'DBO2' 'DSE5' 'DBO1' 'DBO6']
# 18
#
#
# date_YYYY_MM_DD
# ['2018-06-17' '2018-09-03' '2018-09-19' '2018-07-02' '2018-07-11'
#  '2018-07-18' '2018-06-13' '2018-09-29' '2018-06-19' '2018-09-15'
#  '2018-07-01' '2018-06-16' '2018-07-05' '2018-06-07' '2018-06-05'
#  '2018-09-23' '2018-06-02' '2018-08-27' '2018-06-12' '2018-06-26'
#  '2018-08-31' '2018-06-09' '2018-09-26' '2018-06-20' '2018-09-27'
#  '2018-09-14' '2018-06-10' '2018-06-21' '2018-07-16' '2018-09-30'
#  '2018-09-22' '2018-09-04' '2018-09-06' '2018-06-22' '2018-09-10'
#  '2018-07-03' '2018-07-14' '2018-09-21' '2018-09-05' '2018-10-01'
#  '2018-09-01' '2018-07-06' '2018-09-18' '2018-06-01' '2018-09-08'
#  '2018-09-09' '2018-06-03' '2018-09-17' '2018-10-02' '2018-06-24'
#  '2018-08-28' '2018-09-24' '2018-06-29' '2018-09-28' '2018-07-08'
#  '2018-07-12' '2018-09-25' '2018-07-19' '2018-06-04' '2018-09-16'
#  '2018-06-08' '2018-06-06' '2018-06-28' '2018-07-17' '2018-08-29'
#  '2018-09-11' '2018-08-30' '2018-06-27' '2018-09-12' '2018-09-02'
#  '2018-09-20' '2018-07-09' '2018-06-15' '2018-07-10' '2018-06-14'
#  '2018-07-07' '2018-07-15' '2018-09-13' '2018-07-13' '2018-06-23'
#  '2018-09-07' '2018-06-18' '2018-06-11' '2018-06-30' '2018-06-25']
# 85
#
#
# departure_time_utc
# ['17:23:00' '14:48:09' '15:00:43' ... '12:01:18' '13:05:52' '15:42:06']
# 2331
#
#
# executor_capacity_cm3
# [3539605.75 3313071.   4672279.5  3114853.25 4247527.   3398021.5
#  3681190.  ]
# 7
#
#
# Zone
# ['K-21' 'E-4' 'D-1' 'B-10' 'B-9' 'C-9' 'E-8' 'C-13' 'B-5' 'C-12' 'B-8'
#  'C-25' 'B-25' 'C-5' 'C-17' 'C-23' 'H-7' 'C-1' 'D-3' 'H-15' 'H-23' 'A-21'
#  'P-3' 'E-16' 'D-16' 'A-7' 'B-1' 'D-11' 'E-26' 'A-34' 'E-6' 'D-6' 'L-17'
#  'A-10' 'D-24' 'D-9' 'C-2' 'A-33' 'D-7' 'E-9' 'E-10' 'A-2' 'D-10' 'C-22'
#  'L-18' 'P-4' 'S-5' 'L-2' 'P-8' 'M-8' 'J-25' 'G-32' 'D-30' 'M-3' 'O-10'
#  'T-6' 'G-33' 'G-30' 'S-3' 'L-10' 'O-9' 'K-24' 'J-11' 'T-4' 'S-2' 'K-18'
#  'M-13' 'K-12' 'O-3' 'P-6' 'L-12' 'P-7' 'K-15' 'L-26' 'O-8' 'K-22' 'J-13'
#  'L-21' 'E-31' 'O-11' 'B-33' 'B-32' 'M-7' 'F-2']
# 331
#
#
# starting_point
# ['UZ' 'AI' 'BU' 'HI' 'HP' 'BL' 'MN' 'RV' 'BP' 'RG' 'UQ' 'AS' 'HJ' 'GK'
#  'AP' 'NU' 'FO' 'TJ' 'XE' 'OM' 'BY' 'LF' 'WZ' 'OX' 'XJ' 'NS' 'KZ' 'NK'
#  'NP' 'QU' 'TQ' 'IX' 'YV' 'WS' 'WJ' 'QM' 'WT' 'BX' 'XT' 'ZG' 'OL' 'GX'
#  'VE' 'YI' 'TL' 'NO' 'BO' 'HG' 'WQ' 'YU' 'IZ' 'QI' 'XV' 'RT' 'DI' 'QV'
#  'EO' 'NY' 'DF' 'RP' 'BB' 'GM' 'XG' 'ZE' 'ET' 'WM' 'IY' 'UP' 'QF' 'DM'
#  'FJ' 'TG' 'HX' 'SL' 'XB' 'EQ' 'AL' 'PX' 'QE' 'PO' 'GS' 'EJ' 'MP' 'KI'
#  'TA' 'QY' 'KQ' 'CE' 'NJ' 'SP' 'PE' 'VR' 'DK' 'UH' 'AU' 'QK' 'UU' 'BS'
#  'XA' 'TP' 'RJ' 'AM' 'VT' 'RE' 'BV' 'YK' 'WR' 'CX' 'YW' 'EX' 'PU' 'PG'
#  'QO' 'AG' 'UV' 'JA' 'XM' 'FQ' 'XZ' 'AK' 'KJ' 'SX' 'WK' 'UK' 'DT' 'XS'
#  'JE' 'PZ' 'VF' 'QL' 'MC' 'GY' 'RD' 'ZM' 'EA' 'CC' 'QR' 'YB' 'IC' 'YH'
#  'XX' 'QX' 'PQ' 'EK' 'YG' 'DD' 'VN' 'KL' 'VX' 'DV' 'YA' 'TM' 'LM' 'WP'
#  'KC' 'FX' 'HA' 'DP' 'OW' 'WV' 'BC' 'KW' 'DZ' 'PB' 'ED' 'GA' 'AV' 'FK'
#  'HB' 'ON' 'ZP' 'TR' 'JK' 'SQ' 'JV' 'CS' 'IW' 'NW' 'XQ' 'YY' 'NL' 'ZC'
#  'MG' 'MQ' 'UI' 'UB' 'EF' 'XC' 'KH' 'FL' 'SM' 'BJ' 'VL' 'KG' 'GB' 'VV'
#  'WE' 'NC' 'SW' 'KU' 'CD' 'NZ' 'GH' 'NV' 'RL' 'AD' 'ZL' 'CB' 'PC' 'YF'
#  'KY' 'WA' 'IM' 'DY' 'PP' 'MW' 'CT' 'KE' 'LZ' 'VM' 'RW' 'LR' 'MB' 'DC'
#  'AZ' 'RH' 'GI' 'CY' 'RR' 'HH' 'QC' 'SU' 'RN' 'TZ' 'OR' 'HY' 'GR' 'YT'
#  'NR' 'CW' 'CK' 'MI' 'WL' 'KN' 'OV' 'ZR' 'KM' 'MX' 'BT' 'FH' 'UC' 'ZK'
#  'QP' 'OZ' 'PJ' 'SO' 'ZI' 'MO' 'BD' 'EH' 'JQ' 'EU' 'ZQ' 'TE' 'SS' 'KF'
#  'ZD' 'GP' 'LS' 'LT' 'FY' 'IE' 'YZ' 'GD' 'UF' 'OU' 'CG' 'RI' 'JC' 'VZ'
#  'CJ' 'RC' 'IK' 'RQ' 'IN' 'ZH' 'WG' 'RA' 'YL' 'FE' 'MM' 'RF' 'OH' 'TU'
#  'LO' 'YQ' 'NF' 'KV' 'VI' 'VP' 'VG' 'HR' 'UD' 'IO' 'XN' 'IG' 'JD' 'FF'
#  'HS' 'BW' 'PK' 'QZ' 'KS' 'AB' 'FP' 'AE' 'YD' 'PH' 'SV' 'TK' 'JX' 'JZ'
#  'BE' 'FR' 'LJ' 'TS' 'YX' 'CI' 'KR' 'ER' 'PT' 'PM' 'HT' 'IA' 'BK' 'TW'
#  'WN' 'JR' 'HL' 'SE' 'BM' 'AX' 'TT' 'CP' 'YJ' 'HM' 'LP' 'CQ' 'YO' 'OQ'
#  'WI' 'RU' 'GU' 'UW' 'FZ' 'CU' 'HZ' 'TV' 'AH' 'QJ' 'DU' 'TN' 'GC' 'QQ'
#  'TI' 'UX' 'EI' 'HN' 'XF' 'LQ' 'PW' 'OG' 'WX' 'PY' 'KX' 'SG' 'UM' 'HU'
#  'TH' 'WC' 'EM' 'SJ' 'VK' 'XL' 'NM' 'YM' 'PR' 'DG' 'AQ' 'MS']
# 390
#
#
# StopID
# ['AH' 'AJ' 'AL' 'AN' 'AP' 'AS' 'AY' 'BA' 'BB' 'BO' 'BQ' 'BR' 'BU' 'BY'
#  'CC' 'CF' 'CG' 'CL' 'CO' 'CR' 'CW' 'CZ' 'DH' 'DQ' 'DT' 'DU' 'EC' 'EI'
#  'ER' 'EU' 'FC' 'FF' 'FI' 'FO' 'FQ' 'FT' 'FY' 'FZ' 'GC' 'GE' 'GH' 'GL'
#  'GQ' 'GV' 'GW' 'GX' 'GY' 'GZ' 'HH' 'HI' 'HJ' 'HL' 'HM' 'HO' 'HT' 'HV'
#  'IB' 'IL' 'IT' 'IV' 'IX' 'JL' 'JM' 'JN' 'JQ' 'JT' 'JY' 'KG' 'KO' 'LI'
#  'LS' 'MA' 'MD' 'MX' 'NJ' 'NQ' 'NS' 'NT' 'NY' 'OF' 'OI' 'OM' 'OO' 'OQ'
#  'OR' 'OV' 'OY' 'OZ' 'PA' 'PF' 'PU' 'PV' 'PX' 'PY' 'QA' 'QF' 'QK' 'QL'
#  'QT' 'QV' 'QX' 'RC' 'RF' 'RG' 'RT' 'RX' 'RY' 'SE' 'SG' 'SI' 'SN' 'ST'
#  'SY' 'TG' 'TL' 'TM' 'TN' 'TT' 'TX' 'TZ' 'UC' 'UD' 'UH' 'UL' 'UM' 'UP'
#  'UW' 'UY' 'VJ' 'VO' 'VX' 'VY' 'WC' 'WF' 'WG' 'WK' 'WO' 'WQ' 'WR' 'WT'
#  'WU' 'WW' 'XC' 'XG' 'XI' 'XL' 'XR' 'XT' 'YA' 'YH' 'YJ' 'YM' 'YO' 'YR'
#  'YV' 'YY' 'ZA' 'ZB' 'ZC' 'ZE' 'ZF' 'ZJ' 'ZK' 'ZM' 'ZT' 'AQ' 'AU' 'AX'
#  'BG' 'BM' 'BT' 'CN' 'CU' 'CX' 'DM' 'DO' 'DS' 'DV' 'DW' 'EH' 'EM' 'EW'
#  'FJ' 'FK' 'FR' 'FS' 'GK' 'HB' 'HC' 'HE' 'HG' 'ID' 'IE' 'JR' 'KF' 'KJ'
#  'KX' 'KZ' 'LA' 'NA' 'NC' 'NP' 'OL' 'PC' 'PT' 'QI' 'QW' 'RJ' 'RV' 'RZ'
#  'SM' 'TA' 'TD' 'TO' 'TU' 'TW' 'UK' 'UQ' 'UT' 'UU' 'VU' 'VV' 'WH' 'WS'
#  'WV' 'WX' 'XE' 'YD' 'YZ' 'ZI' 'ZL' 'ZW' 'AC' 'AD' 'AG' 'AR' 'AZ' 'BE'
#  'BJ' 'BN' 'BP' 'BX' 'BZ' 'CE' 'CY' 'DI' 'DL' 'DN' 'DX' 'DZ' 'EE' 'ET'
#  'EY' 'FL' 'FV' 'GG' 'GR' 'IF' 'II' 'IK' 'IO' 'IQ' 'JE' 'JU' 'JZ' 'KH'
#  'KL' 'KR' 'KS' 'KY' 'LG' 'LL' 'LZ' 'MM' 'MZ' 'NB' 'ND' 'NG' 'NH' 'NL'
#  'NW' 'OE' 'OJ' 'OU' 'PB' 'PE' 'PH' 'PM' 'PO' 'PQ' 'QC' 'QO' 'RK' 'SD'
#  'SR' 'SU' 'TJ' 'TR' 'UE' 'UI' 'UJ' 'US' 'UV' 'VA' 'VB' 'VM' 'WM' 'XK'
#  'XO' 'XQ' 'XU' 'YG' 'YW' 'ZG' 'ZO' 'ZP' 'ZV' 'ZX' 'AA' 'AM' 'BC' 'BS'
#  'CJ' 'CM' 'DB' 'DD' 'DF' 'DG' 'DR' 'EB' 'ED' 'EK' 'EO' 'EV' 'FG' 'FN'
#  'FW' 'GI' 'GJ' 'GM' 'GN' 'HR' 'HS' 'HW' 'HY' 'IG' 'IJ' 'IU' 'JH' 'JI'
#  'JK' 'JS' 'JV' 'JW' 'KI' 'KP' 'KV' 'LN' 'LR' 'LT' 'LV' 'ME' 'MG' 'MJ'
#  'MO' 'MS' 'NU' 'NX' 'NZ' 'OA' 'OB' 'ON' 'OT' 'OX' 'PJ' 'PK' 'PL' 'PR'
#  'QD' 'QG' 'QM' 'QS' 'QY' 'RB' 'RO' 'SF' 'SJ' 'SK' 'SO' 'TB' 'TE' 'TY'
#  'UA' 'UN' 'VC' 'VN' 'WA' 'WI' 'WL' 'WN' 'XB' 'XJ' 'XW' 'YB' 'YE' 'YF'
#  'YI' 'YK' 'YP' 'YQ' 'YX' 'ZN' 'ZU' 'BK' 'BV' 'CH' 'CK' 'CP' 'DA' 'EG'
#  'EQ' 'FB' 'FM' 'HN' 'KE' 'KW' 'LQ' 'LW' 'MC' 'MH' 'MV' 'NN' 'NO' 'OC'
#  'OH' 'OK' 'OW' 'QN' 'QP' 'RH' 'RI' 'TC' 'UZ' 'VL' 'VT' 'WD' 'AB' 'AO'
#  'AV' 'BF' 'CQ' 'DE' 'DJ' 'DK' 'EJ' 'FE' 'GO' 'GS' 'GU' 'HP' 'IC' 'IP'
#  'IS' 'JA' 'JD' 'JG' 'JO' 'KA' 'KD' 'KU' 'LE' 'LK' 'LU' 'MB' 'MN' 'MP'
#  'MT' 'MU' 'MY' 'NE' 'NI' 'NM' 'NR' 'PZ' 'RQ' 'RS' 'RU' 'SA' 'SW' 'TK'
#  'TQ' 'UG' 'VK' 'WJ' 'WZ' 'XS' 'XZ' 'YL' 'YT' 'ZH' 'BD' 'BI' 'CS' 'CT'
#  'DY' 'EZ' 'FD' 'FP' 'FU' 'GD' 'GP' 'HQ' 'IA' 'IM' 'IY' 'JJ' 'KB' 'LJ'
#  'MF' 'MR' 'NK' 'PD' 'PG' 'PI' 'QH' 'SB' 'SL' 'SV' 'TI' 'TP' 'TS' 'TV'
#  'UF' 'WY' 'ZD' 'ZY' 'AI' 'AW' 'CB' 'CV' 'DP' 'FA' 'IH' 'IZ' 'JP' 'KM'
#  'KQ' 'LD' 'LF' 'ML' 'MW' 'NV' 'PS' 'QE' 'QJ' 'QR' 'RA' 'RE' 'SC' 'SQ'
#  'UX' 'VG' 'WE' 'WP' 'XD' 'XN' 'XP' 'XY' 'ZQ' 'ZR' 'AT' 'CD' 'DC' 'EF'
#  'EN' 'FX' 'GA' 'GF' 'GT' 'HZ' 'IR' 'IW' 'JF' 'LH' 'LY' 'MK' 'MQ' 'OG'
#  'PW' 'QQ' 'QZ' 'RD' 'RL' 'RW' 'SS' 'SX' 'TF' 'UB' 'VE' 'VF' 'VW' 'XA'
#  'XF' 'YC' 'YU' 'HA' 'HF' 'KN' 'LM' 'QB' 'QU' 'SH' 'SP' 'VQ' 'VZ' 'WB'
#  'XM' 'YS' 'CA' 'CI' 'EP' 'EX' 'HD' 'IN' 'JC' 'KC' 'LC' 'NF' 'RR' 'AF'
#  'BL' 'EL' 'HK' 'KK' 'KT' 'LB' 'LO' 'OP' 'PN' 'RP' 'TH' 'UR' 'ES' 'HU'
#  'HX' 'MI' 'RN' 'VI' 'VR' 'JX' 'LP' 'VS' 'ZS' 'AK' 'BW' 'GB' 'OD' 'XH'
#  'YN' 'EA' 'FH' 'JB' 'OS' 'VD' 'VH' 'XX' 'AE' 'PP' 'UO' 'RM' 'SZ' 'BH'
#  'LX' 'VP' 'XV']
# 675
#
#
# PackageID
# ['PackageID_fd17bd67-a3d8-45b9-936b-c7e9d879102e'
#  'PackageID_f78261e7-4c8c-4d72-b007-9934a53a700b'
#  'PackageID_a8e394ee-4208-412d-8b34-8cbce880a322' ...
# 607
#
#
# time_to_arrive
# [703.9 670.6 789.6 ... 380.5 442.1 415.5]
# 33014
#
#
# day_of_week
# ['Sunday' 'Monday' 'Wednesday' 'Saturday' 'Tuesday' 'Thursday' 'Friday']
# 7
#
#
# month
# [ 6  9  7  8 10]
# 5
#
#
# StartLat
# [33.918699 34.23485  47.937344 34.007369 33.688122 30.445236 33.965477
#  42.254346 42.139891 47.54217  41.803295 41.840375 42.031368 33.937865
#  42.233353 47.464945 42.394375 42.791897]
# 18
#
#
# StartLon
# [-118.324843 -118.58421  -122.244952 -118.143927 -117.847178  -97.709418
#  -117.653303  -87.985697  -71.494346 -122.328049  -88.097259  -87.683736
#   -87.776596 -117.29738   -71.141617 -122.231073  -71.055555  -71.529552]
# 18
#
#
# StopLat
# [33.88548  33.902808 33.893616 ... 34.147978 34.159877 34.155712]
# 338428
#
#
# StopLon
# [-118.344553 -118.355223 -118.358108 ... -117.502335 -117.528523
#  -117.508143]
# 349185
#
#
# distance_lat
# [0.033219 0.015891 0.025083 ... 0.197759 0.182501 0.1944  ]
# 194369
#
#
# distance_lon
# [0.01971  0.03038  0.033265 ... 0.153295 0.154982 0.128597]
# 210880
#
#
# executor_capacity_cm3_discret
# ['<4', '>4.5', '<4 <4.5']
# Categories (3, object): ['<4' < '<4 <4.5' < '>4.5']
# 3

# %%
pd.value_counts(combined_dataset['Zone'])
# Out:
# C:\Users\tatys\AppData\Local\Temp\ipykernel_528\1203748804.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(combined_dataset['Zone'])
# Zone
# C-5     8852
# C-2     8798
# A-2     8706
# A-3     8624
# C-6     8188
#         ...
# O-8      196
# M-13     186
# L-20     186
# O-9      175
# M-1      171
# Name: count, Length: 331, dtype: int64

# %%
#plot = combined_dataset['Zone'].value_counts().plot(kind='bar',
                                            title='Zonas de reparto')

# %%
pd.value_counts(combined_dataset['day_of_week'])
# Out:
# C:\Users\tatys\AppData\Local\Temp\ipykernel_528\3101020061.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(combined_dataset['day_of_week'])
# day_of_week
# Saturday     125662
# Tuesday      122525
# Thursday     105262
# Sunday       100136
# Wednesday     92128
# Friday        84804
# Monday        84052
# Name: count, dtype: int64

# %%
plot = combined_dataset['day_of_week'].value_counts().plot(kind='bar',
                                            title='Deliveries by days of the week')

# %%
pd.value_counts(combined_dataset['month'])
# Out:
# C:\Users\tatys\AppData\Local\Temp\ipykernel_528\3588987962.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(combined_dataset['month'])
# month
# 9     286321
# 6     205432
# 7     168884
# 8      32366
# 10     21566
# Name: count, dtype: int64

# %%
plot = combined_dataset['month'].value_counts().plot(kind='bar',
                                            title='Deliveries by days of the month')

# %%
#Contingency table day_of_week/month
pd.crosstab(index=combined_dataset['month'],
            columns=combined_dataset['day_of_week'], margins=True)
# Out:
# day_of_week  Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday  \
# month
# 6             30477   17497     45517   27522     28854    27379      28186
# 7             14755   25694     19247   20800     30883    39042      18463
# 8              5959    2914         0       0      7112     8129       8252
# 9             33613   31130     60898   51814     38413    33226      37227
# 10                0    6817         0       0         0    14749          0
# All           84804   84052    125662  100136    105262   122525      92128
#
# day_of_week     All
# month
# 6            205432
# 7            168884
# 8             32366
# 9            286321
# 10            21566
# All          714569

# %%
# Contingency table in total relative percentages
pd.crosstab(index=combined_dataset['month'], columns=combined_dataset['day_of_week'],
            margins=True).apply(lambda r: r/len(combined_dataset) *100,axis=1)
# Out:
# day_of_week     Friday     Monday   Saturday     Sunday   Thursday    Tuesday  \
# month
# 6             4.265088   2.448609   6.369854   3.851552   4.037959   3.831540
# 7             2.064881   3.595734   2.693512   2.910846   4.321906   5.463713
# 8             0.833929   0.407798   0.000000   0.000000   0.995285   1.137609
# 9             4.703954   4.356472   8.522340   7.251084   5.375688   4.649796
# 10            0.000000   0.954002   0.000000   0.000000   0.000000   2.064041
# All          11.867853  11.762615  17.585706  14.013482  14.730838  17.146700
#
# day_of_week  Wednesday         All
# month
# 6             3.944476   28.749078
# 7             2.583795   23.634387
# 8             1.154822    4.529444
# 9             5.209714   40.069049
# 10            0.000000    3.018043
# All          12.892807  100.000000

# %%
# Contingency table in relative percentages according to day of the week
pd.crosstab(index=combined_dataset['date_YYYY_MM_DD'], columns=combined_dataset['month']
           ).apply(lambda r: r/r.sum() *100,
                                axis=1)
# Out:
# month               6    7    8      9      10
# date_YYYY_MM_DD
# 2018-06-01       100.0  0.0  0.0    0.0    0.0
# 2018-06-02       100.0  0.0  0.0    0.0    0.0
# 2018-06-03       100.0  0.0  0.0    0.0    0.0
# 2018-06-04       100.0  0.0  0.0    0.0    0.0
# 2018-06-05       100.0  0.0  0.0    0.0    0.0
# ...                ...  ...  ...    ...    ...
# 2018-09-28         0.0  0.0  0.0  100.0    0.0
# 2018-09-29         0.0  0.0  0.0  100.0    0.0
# 2018-09-30         0.0  0.0  0.0  100.0    0.0
# 2018-10-01         0.0  0.0  0.0    0.0  100.0
# 2018-10-02         0.0  0.0  0.0    0.0  100.0
#
# [85 rows x 5 columns]

# %%
# Contingency table in relative percentages according to month
pd.crosstab(index=combined_dataset['day_of_week'], columns=combined_dataset['month']
           ).apply(lambda r: r/r.sum() *100,
                                axis=0)
# Out:
# month               6          7          8          9          10
# day_of_week
# Friday       14.835566   8.736766  18.411296  11.739621   0.000000
# Monday        8.517174  15.213993   9.003275  10.872412  31.609942
# Saturday     22.156723  11.396580   0.000000  21.269135   0.000000
# Sunday       13.397134  12.316146   0.000000  18.096472   0.000000
# Thursday     14.045524  18.286516  21.973676  13.416061   0.000000
# Tuesday      13.327524  23.117643  25.115862  11.604458  68.390058
# Wednesday    13.720355  10.932356  25.495891  13.001841   0.000000

# %%
# Bar chart of month by day of the week
plot = pd.crosstab(index=combined_dataset['day_of_week'],
            columns=combined_dataset['month']).apply(lambda r: r/r.sum() *100,
                                              axis=1).plot(kind='bar')

# %%
# Bar chart of month by day of the week
plot = pd.crosstab(index=combined_dataset['day_of_week'],
            columns=combined_dataset['month']
                  ).apply(lambda r: r/r.sum() *100,
                          axis=0).plot(kind='bar', stacked=True)
