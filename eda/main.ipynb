# %% [markdown]
# # EDA Combined preprocessed dataset

# %%
import pandas as pd

# %%
COMBINED_PREPROCESSED_DATASET_PATH = "../datasets/preprocessed/combined_dataset.json"
combined_dataset = pd.read_json(COMBINED_PREPROCESSED_DATASET_PATH)
combined_dataset
# Out:
#                                              RouteID station_code  \
# 0       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8
# 1       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8
# 2       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8
# 3       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8
# 4       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8
# ...                                              ...          ...
# 714564  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee         DLA7
# 714565  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee         DLA7
# 714566  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee         DLA7
# 714567  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee         DLA7
# 714568  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee         DLA7
#
#        date_YYYY_MM_DD departure_time_utc  executor_capacity_cm3  Zone  \
# 0           2018-06-17           17:23:00             3539605.75  K-21
# 1           2018-06-17           17:23:00             3539605.75  K-21
# 2           2018-06-17           17:23:00             3539605.75  K-21
# 3           2018-06-17           17:23:00             3539605.75  K-21
# 4           2018-06-17           17:23:00             3539605.75  K-21
# ...                ...                ...                    ...   ...
# 714564      2018-07-08           15:42:06             3539605.75  G-18
# 714565      2018-07-08           15:42:06             3539605.75  G-18
# 714566      2018-07-08           15:42:06             3539605.75  G-18
# 714567      2018-07-08           15:42:06             3539605.75  G-18
# 714568      2018-07-08           15:42:06             3539605.75  G-18
#
#        starting_point StopID                                       PackageID  \
# 0                  UZ     AH  PackageID_fd17bd67-a3d8-45b9-936b-c7e9d879102e
# 1                  UZ     AH  PackageID_f78261e7-4c8c-4d72-b007-9934a53a700b
# 2                  UZ     AJ  PackageID_a8e394ee-4208-412d-8b34-8cbce880a322
# 3                  UZ     AL  PackageID_b7c39ed4-fa0a-497a-ae0c-e3515734f8ae
# 4                  UZ     AL  PackageID_e980c24b-ab88-4af1-b3f9-1f851823f561
# ...               ...    ...                                             ...
# 714564             XL     YU  PackageID_b0bad72b-041e-4b5b-8303-03131c837b8d
# 714565             XL     YU  PackageID_b2c6f0de-6fcf-4616-b2cd-ba63ef6d0715
# 714566             XL     YU  PackageID_3de4b3fd-d80d-4ae7-a519-c82a4e46c48c
# 714567             XL     ZQ  PackageID_59aae7fe-cbb2-47c8-8c2f-59a97154ccd9
# 714568             XL     ZS  PackageID_267d089c-6c82-49b0-80f8-6748db36c8dc
#
#         planned_service_time_seconds  ...  weight_cm  time_to_arrive  \
# 0                               31.5  ...       30.5           703.9
# 1                               31.5  ...       17.8           703.9
# 2                               40.0  ...       17.8           670.6
# 3                               47.0  ...       21.8           789.6
# 4                               47.0  ...       35.6           789.6
# ...                              ...  ...        ...             ...
# 714564                          38.3  ...       40.6          2386.8
# 714565                          38.3  ...       41.3          2386.8
# 714566                          38.3  ...       36.8          2386.8
# 714567                         102.0  ...       33.0          2568.5
# 714568                          74.0  ...       13.7          2588.5
#
#         day_of_week  month   StartLat    StartLon    StopLat     StopLon  \
# 0            Sunday      6  33.918699 -118.324843  33.885480 -118.344553
# 1            Sunday      6  33.918699 -118.324843  33.885480 -118.344553
# 2            Sunday      6  33.918699 -118.324843  33.902808 -118.355223
# 3            Sunday      6  33.918699 -118.324843  33.893616 -118.358108
# 4            Sunday      6  33.918699 -118.324843  33.893616 -118.358108
# ...             ...    ...        ...         ...        ...         ...
# 714564       Sunday      7  33.965477 -117.653303  34.152862 -117.502335
# 714565       Sunday      7  33.965477 -117.653303  34.152862 -117.502335
# 714566       Sunday      7  33.965477 -117.653303  34.152862 -117.502335
# 714567       Sunday      7  33.965477 -117.653303  34.155712 -117.528523
# 714568       Sunday      7  33.965477 -117.653303  34.161928 -117.508143
#
#         distance_lat  distance_lon
# 0           0.033219      0.019710
# 1           0.033219      0.019710
# 2           0.015891      0.030380
# 3           0.025083      0.033265
# 4           0.025083      0.033265
# ...              ...           ...
# 714564      0.187385      0.150968
# 714565      0.187385      0.150968
# 714566      0.187385      0.150968
# 714567      0.190235      0.124780
# 714568      0.196451      0.145160
#
# [714569 rows x 22 columns]

# %%
from matplotlib import pyplot as plt
import seaborn as sns
fig, ax1=plt.subplots(1,3)
ax2 = ax1.ravel()
fig.set_figheight(4)
fig.set_figwidth(15)
plt.subplots_adjust(hspace=0.3)
sns.histplot(combined_dataset['executor_capacity_cm3'], kde=True, ax=ax2[0],stat='percent',bins=10)
sns.histplot(combined_dataset['executor_capacity_cm3'], kde=True, ax=ax2[1],stat='percent', bins=5)
sns.histplot(combined_dataset['executor_capacity_cm3'], kde=True, ax=ax2[2],stat='percent', bins=3)
# Out:
# D:\GitHub Repos\Proyecto_Mineria\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\GitHub Repos\Proyecto_Mineria\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\GitHub Repos\Proyecto_Mineria\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\GitHub Repos\Proyecto_Mineria\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\GitHub Repos\Proyecto_Mineria\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\GitHub Repos\Proyecto_Mineria\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='executor_capacity_cm3', ylabel='Percent'>

# %%
limits = [0*10**6,4*10**6,4.5*10**6,5*10**6]
category_executor = ['<4','<4 <4.5', '>4.5']
combined_dataset['executor_capacity_cm3_discret'] = pd.cut(combined_dataset['executor_capacity_cm3'], bins=limits, labels=category_executor)

# %%
combined_dataset.head()
# Out:
#                                         RouteID station_code date_YYYY_MM_DD  \
# 0  RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8      2018-06-17
# 1  RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8      2018-06-17
# 2  RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8      2018-06-17
# 3  RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8      2018-06-17
# 4  RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8      2018-06-17
#
#   departure_time_utc  executor_capacity_cm3  Zone starting_point StopID  \
# 0           17:23:00             3539605.75  K-21             UZ     AH
# 1           17:23:00             3539605.75  K-21             UZ     AH
# 2           17:23:00             3539605.75  K-21             UZ     AJ
# 3           17:23:00             3539605.75  K-21             UZ     AL
# 4           17:23:00             3539605.75  K-21             UZ     AL
#
#                                         PackageID  \
# 0  PackageID_fd17bd67-a3d8-45b9-936b-c7e9d879102e
# 1  PackageID_f78261e7-4c8c-4d72-b007-9934a53a700b
# 2  PackageID_a8e394ee-4208-412d-8b34-8cbce880a322
# 3  PackageID_b7c39ed4-fa0a-497a-ae0c-e3515734f8ae
# 4  PackageID_e980c24b-ab88-4af1-b3f9-1f851823f561
#
#    planned_service_time_seconds  ...  time_to_arrive  day_of_week  month  \
# 0                          31.5  ...           703.9       Sunday      6
# 1                          31.5  ...           703.9       Sunday      6
# 2                          40.0  ...           670.6       Sunday      6
# 3                          47.0  ...           789.6       Sunday      6
# 4                          47.0  ...           789.6       Sunday      6
#
#     StartLat    StartLon    StopLat     StopLon  distance_lat  distance_lon  \
# 0  33.918699 -118.324843  33.885480 -118.344553      0.033219      0.019710
# 1  33.918699 -118.324843  33.885480 -118.344553      0.033219      0.019710
# 2  33.918699 -118.324843  33.902808 -118.355223      0.015891      0.030380
# 3  33.918699 -118.324843  33.893616 -118.358108      0.025083      0.033265
# 4  33.918699 -118.324843  33.893616 -118.358108      0.025083      0.033265
#
#    executor_capacity_cm3_discret
# 0                             <4
# 1                             <4
# 2                             <4
# 3                             <4
# 4                             <4
#
# [5 rows x 23 columns]

# %%
combined_dataset_colums = combined_dataset.columns.tolist()
no_discrete = combined_dataset_colums.copy()

no_discrete.pop()
print(no_discrete)
# Out:
# ['RouteID', 'station_code', 'date_YYYY_MM_DD', 'departure_time_utc', 'executor_capacity_cm3', 'Zone', 'starting_point', 'StopID', 'PackageID', 'planned_service_time_seconds', 'depth_cm', 'height_cm', 'weight_cm', 'time_to_arrive', 'day_of_week', 'month', 'StartLat', 'StartLon', 'StopLat', 'StopLon', 'distance_lat', 'distance_lon']

# %%
pd.crosstab(combined_dataset['executor_capacity_cm3_discret'], combined_dataset['Zone'], combined_dataset['starting_point'], margins=True, margins_name='Total', aggfunc= ',')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 pd.crosstab(combined_dataset['executor_capacity_cm3_discret'], combined_dataset['Zone'], combined_dataset['starting_point'], margins=True, margins_name='Total', aggfunc= ',')
#
# File D:\GitHub Repos\Proyecto_Mineria\venv\Lib\site-packages\pandas\core\reshape\pivot.py:711, in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     707     kwargs = {"aggfunc": aggfunc}
#     709 # error: Argument 7 to "pivot_table" of "DataFrame" has incompatible type
#     710 # "**Dict[str, object]"; expected "Union[...]"
# --> 711 table = df.pivot_table(
#     712     "__dummy__",
#     713     index=unique_rownames,
#     714     columns=unique_colnames,
#     715     margins=margins,
#     716     margins_name=margins_name,
#     717     dropna=dropna,
#     718     **kwargs,  # type: ignore[arg-type]
#     719 )
#     721 # Post-process
#     722 if normalize is not False:
#
# File D:\GitHub Repos\Proyecto_Mineria\venv\Lib\site-packages\pandas\core\frame.py:9193, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9176 @Substitution("")
#    9177 @Appender(_shared_docs["pivot_table"])
#    9178 def pivot_table(
#    (...)
#    9189     sort: bool = True,
#    9190 ) -> DataFrame:
#    9191     from pandas.core.reshape.pivot import pivot_table
# -> 9193     return pivot_table(
#    9194         self,
#    9195         values=values,
#    9196         index=index,
#    9197         columns=columns,
#    9198         aggfunc=aggfunc,
#    9199         fill_value=fill_value,
#    9200         margins=margins,
#    9201         dropna=dropna,
#    9202         margins_name=margins_name,
#    9203         observed=observed,
#    9204         sort=sort,
#    9205     )
#
# File D:\GitHub Repos\Proyecto_Mineria\venv\Lib\site-packages\pandas\core\reshape\pivot.py:99, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      96     table = concat(pieces, keys=keys, axis=1)
#      97     return table.__finalize__(data, method="pivot_table")
# ---> 99 table = __internal_pivot_table(
#     100     data,
#     101     values,
#     102     index,
#     103     columns,
#     104     aggfunc,
#     105     fill_value,
#     106     margins,
#     107     dropna,
#     108     margins_name,
#     109     observed,
#     110     sort,
#     111 )
#     112 return table.__finalize__(data, method="pivot_table")
#
# File D:\GitHub Repos\Proyecto_Mineria\venv\Lib\site-packages\pandas\core\reshape\pivot.py:169, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     166     values = list(values)
#     168 grouped = data.groupby(keys, observed=observed, sort=sort, dropna=dropna)
# --> 169 agged = grouped.agg(aggfunc)
#     171 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     172     agged = agged.dropna(how="all")
#
# File D:\GitHub Repos\Proyecto_Mineria\venv\Lib\site-packages\pandas\core\groupby\generic.py:1442, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1439     kwargs["engine_kwargs"] = engine_kwargs
#    1441 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1442 result = op.agg()
#    1443 if not is_dict_like(func) and result is not None:
#    1444     # GH #52849
#    1445     if not self.as_index and is_list_like(func):
#
# File D:\GitHub Repos\Proyecto_Mineria\venv\Lib\site-packages\pandas\core\apply.py:172, in Apply.agg(self)
#     169 kwargs = self.kwargs
#     171 if isinstance(func, str):
# --> 172     return self.apply_str()
#     174 if is_dict_like(func):
#     175     return self.agg_dict_like()
#
# File D:\GitHub Repos\Proyecto_Mineria\venv\Lib\site-packages\pandas\core\apply.py:586, in Apply.apply_str(self)
#     584         else:
#     585             self.kwargs["axis"] = self.axis
# --> 586 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File D:\GitHub Repos\Proyecto_Mineria\venv\Lib\site-packages\pandas\core\apply.py:682, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     680 else:
#     681     msg = f"'{func}' is not a valid function for '{type(obj).__name__}' object"
# --> 682     raise AttributeError(msg)
#
# AttributeError: ',' is not a valid function for 'DataFrameGroupBy' object
