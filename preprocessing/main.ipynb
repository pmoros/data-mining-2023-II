# %% [markdown]
# # Combined preprocessing of the datasets

# %% [markdown]
# ## Utils

# %% [markdown]
# ## Preprocessing Phase 2

# %% [markdown]
# ### Overview

# %% [markdown]
# The goal of this second part is to combine the different datasources that have been partially processed.

# %%
import pandas as pd

# %%
PACKAGE_DATA_PREPROCESSED_DATASET_PATH = "../datasets/preprocessed/eval_package_data_formatted.json"
df_package_data = pd.read_json(PACKAGE_DATA_PREPROCESSED_DATASET_PATH)
df_package_data
# Out:
#                                              RouteID StopID  \
# 0       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e     AH
# 1       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e     AH
# 2       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e     AJ
# 3       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e     AL
# 4       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e     AL
# ...                                              ...    ...
# 724908  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee     YU
# 724909  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee     YU
# 724910  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee     YU
# 724911  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee     ZQ
# 724912  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee     ZS
#
#                                              PackageID  \
# 0       PackageID_fd17bd67-a3d8-45b9-936b-c7e9d879102e
# 1       PackageID_f78261e7-4c8c-4d72-b007-9934a53a700b
# 2       PackageID_a8e394ee-4208-412d-8b34-8cbce880a322
# 3       PackageID_b7c39ed4-fa0a-497a-ae0c-e3515734f8ae
# 4       PackageID_e980c24b-ab88-4af1-b3f9-1f851823f561
# ...                                                ...
# 724908  PackageID_b0bad72b-041e-4b5b-8303-03131c837b8d
# 724909  PackageID_b2c6f0de-6fcf-4616-b2cd-ba63ef6d0715
# 724910  PackageID_3de4b3fd-d80d-4ae7-a519-c82a4e46c48c
# 724911  PackageID_59aae7fe-cbb2-47c8-8c2f-59a97154ccd9
# 724912  PackageID_267d089c-6c82-49b0-80f8-6748db36c8dc
#
#         planned_service_time_seconds  depth_cm  height_cm  weight_cm
# 0                               31.5      40.6       12.7       30.5
# 1                               31.5      25.4       12.7       17.8
# 2                               40.0      25.4       12.7       17.8
# 3                               47.0      37.1        6.1       21.8
# 4                               47.0      44.5       20.3       35.6
# ...                              ...       ...        ...        ...
# 724908                          38.3      66.0       17.8       40.6
# 724909                          38.3      61.6       10.8       41.3
# 724910                          38.3      48.3       30.5       36.8
# 724911                         102.0      48.3       15.2       33.0
# 724912                          74.0      21.3        4.1       13.7
#
# [724913 rows x 7 columns]

# %%
ROUTE_DATA_PREPROCESSED_DATASET_PATH = "../datasets/preprocessed/eval_route_data_formatted.json"

df_eval_route = pd.read_json(ROUTE_DATA_PREPROCESSED_DATASET_PATH, orient='records')
df_eval_route
# Out:
#                                            RouteID station_code  \
# 0     RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8
# 1     RouteID_00337a3a-19c6-4821-9350-ad3cf0532047         DLA4
# 2     RouteID_0034b931-97a7-485f-a6b3-b22798489094         DLA4
# 3     RouteID_0085d8a2-71a3-4205-9c46-e62139eca47b         DSE4
# 4     RouteID_008bf177-673c-4647-89dd-bf8c13b7c51d         DLA3
# ...                                            ...          ...
# 3002  RouteID_fe892b64-84ad-48d5-aede-f65d2e4a3123         DLA7
# 3003  RouteID_feb2d877-9478-474c-8f88-6f93ce2ac6aa         DLA8
# 3004  RouteID_fedf4c2f-2618-4598-bfb5-ec90822c9a29         DBO3
# 3005  RouteID_ff30c100-6266-461d-9c56-939775a1defe         DBO1
# 3006  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee         DLA7
#
#      date_YYYY_MM_DD departure_time_utc  executor_capacity_cm3  Zone  \
# 0         2018-06-17           17:23:00             3539605.75  K-21
# 1         2018-09-03           14:48:09             3313071.00   E-4
# 2         2018-09-19           15:00:43             3313071.00   D-1
# 3         2018-07-02           15:18:39             3539605.75  B-10
# 4         2018-07-11           15:30:00             3313071.00   B-9
# ...              ...                ...                    ...   ...
# 3002      2018-09-09           14:20:14             3313071.00  E-26
# 3003      2018-06-26           16:35:12             3539605.75  D-23
# 3004      2018-09-17           12:01:18             4247527.00   H-2
# 3005      2018-09-18           13:05:52             4247527.00   H-7
# 3006      2018-07-08           15:42:06             3539605.75  G-18
#
#      starting_point
# 0                UZ
# 1                AI
# 2                BU
# 3                HI
# 4                HP
# ...             ...
# 3002             YY
# 3003             OX
# 3004             YL
# 3005             UI
# 3006             XL
#
# [3007 rows x 7 columns]

# %% [markdown]
# ### Data Integration

# %%
# merge df eval route and df package data
df_eval_route_package_data = pd.merge(df_eval_route, df_package_data, on='RouteID')
df_eval_route_package_data
# Out:
#                                              RouteID station_code  \
# 0       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8
# 1       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8
# 2       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8
# 3       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8
# 4       RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e         DLA8
# ...                                              ...          ...
# 714564  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee         DLA7
# 714565  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee         DLA7
# 714566  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee         DLA7
# 714567  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee         DLA7
# 714568  RouteID_ffdd3b7f-9de4-4a0b-8c07-d186bf7f2dee         DLA7
#
#        date_YYYY_MM_DD departure_time_utc  executor_capacity_cm3  Zone  \
# 0           2018-06-17           17:23:00             3539605.75  K-21
# 1           2018-06-17           17:23:00             3539605.75  K-21
# 2           2018-06-17           17:23:00             3539605.75  K-21
# 3           2018-06-17           17:23:00             3539605.75  K-21
# 4           2018-06-17           17:23:00             3539605.75  K-21
# ...                ...                ...                    ...   ...
# 714564      2018-07-08           15:42:06             3539605.75  G-18
# 714565      2018-07-08           15:42:06             3539605.75  G-18
# 714566      2018-07-08           15:42:06             3539605.75  G-18
# 714567      2018-07-08           15:42:06             3539605.75  G-18
# 714568      2018-07-08           15:42:06             3539605.75  G-18
#
#        starting_point StopID                                       PackageID  \
# 0                  UZ     AH  PackageID_fd17bd67-a3d8-45b9-936b-c7e9d879102e
# 1                  UZ     AH  PackageID_f78261e7-4c8c-4d72-b007-9934a53a700b
# 2                  UZ     AJ  PackageID_a8e394ee-4208-412d-8b34-8cbce880a322
# 3                  UZ     AL  PackageID_b7c39ed4-fa0a-497a-ae0c-e3515734f8ae
# 4                  UZ     AL  PackageID_e980c24b-ab88-4af1-b3f9-1f851823f561
# ...               ...    ...                                             ...
# 714564             XL     YU  PackageID_b0bad72b-041e-4b5b-8303-03131c837b8d
# 714565             XL     YU  PackageID_b2c6f0de-6fcf-4616-b2cd-ba63ef6d0715
# 714566             XL     YU  PackageID_3de4b3fd-d80d-4ae7-a519-c82a4e46c48c
# 714567             XL     ZQ  PackageID_59aae7fe-cbb2-47c8-8c2f-59a97154ccd9
# 714568             XL     ZS  PackageID_267d089c-6c82-49b0-80f8-6748db36c8dc
#
#         planned_service_time_seconds  depth_cm  height_cm  weight_cm
# 0                               31.5      40.6       12.7       30.5
# 1                               31.5      25.4       12.7       17.8
# 2                               40.0      25.4       12.7       17.8
# 3                               47.0      37.1        6.1       21.8
# 4                               47.0      44.5       20.3       35.6
# ...                              ...       ...        ...        ...
# 714564                          38.3      66.0       17.8       40.6
# 714565                          38.3      61.6       10.8       41.3
# 714566                          38.3      48.3       30.5       36.8
# 714567                         102.0      48.3       15.2       33.0
# 714568                          74.0      21.3        4.1       13.7
#
# [714569 rows x 13 columns]

# %% [markdown]
# ### Feature Extraction

# %% [markdown]
# ### 1. Add time to arrive feature

# %%
import json

TRAVEL_TIMES_RAW_DATASET_PATH = "../datasets/raw/eval_travel_times_formatted.json"

with open(TRAVEL_TIMES_RAW_DATASET_PATH,"r") as travel_times_file:
    travel_times_data = json.load(travel_times_file)

# %%
# Get time to reach stop from source
def get_time_to_reach_stop_from_source(route, source, stop):
    return travel_times_data[route][source][stop]

# %%
# Create a new column time_to_arrive that applies the get_time_to_reach_stop_from_source function to RouteID, starting_point, and StopID
df_eval_route_package_data['time_to_arrive'] = df_eval_route_package_data.apply(lambda row: get_time_to_reach_stop_from_source(row['RouteID'], row['starting_point'], row['StopID']), axis=1)
df_eval_route_package_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/sandbox/university/data-mining/data-mining-2023-II/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/pmoros/sandbox/university/data-mining/data-mining-2023-II/preprocessing/main.ipynb Cell 16 line 2
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pmoros/sandbox/university/data-mining/data-mining-2023-II/preprocessing/main.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # Create a new column time_to_arrive that applies the get_time_to_reach_stop_from_source function to RouteID, starting_point, and StopID
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pmoros/sandbox/university/data-mining/data-mining-2023-II/preprocessing/main.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> df_eval_route_package_data['time_to_arrive'] = df_eval_route_package_data.apply(lambda row: get_time_to_reach_stop_from_source(row['RouteID'], row['starting_point'], row['StopID']), axis=1)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pmoros/sandbox/university/data-mining/data-mining-2023-II/preprocessing/main.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> df_eval_route_package_data
#
# File ~/sandbox/university/data-mining/data-mining-2023-II/venv/lib/python3.10/site-packages/pandas/core/frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File ~/sandbox/university/data-mining/data-mining-2023-II/venv/lib/python3.10/site-packages/pandas/core/apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File ~/sandbox/university/data-mining/data-mining-2023-II/venv/lib/python3.10/site-packages/pandas/core/apply.py:963, in FrameApply.apply_standard(self)
#     962 def apply_standard(self):
# --> 963     results, res_index = self.apply_series_generator()
#     965     # wrap results
#     966     return self.wrap_results(results, res_index)
#
# File ~/sandbox/university/data-mining/data-mining-2023-II/venv/lib/python3.10/site-packages/pandas/core/apply.py:979, in FrameApply.apply_series_generator(self)
#     976 with option_context("mode.chained_assignment", None):
#     977     for i, v in enumerate(series_gen):
#     978         # ignore SettingWithCopy here in case the user mutates
# --> 979         results[i] = self.func(v, *self.args, **self.kwargs)
#     980         if isinstance(results[i], ABCSeries):
#     981             # If we have a view on v, we need to make a copy because
#     982             #  series_generator will swap out the underlying data
#     983             results[i] = results[i].copy(deep=False)
#
# /home/pmoros/sandbox/university/data-mining/data-mining-2023-II/preprocessing/main.ipynb Cell 16 line 2
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pmoros/sandbox/university/data-mining/data-mining-2023-II/preprocessing/main.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # Create a new column time_to_arrive that applies the get_time_to_reach_stop_from_source function to RouteID, starting_point, and StopID
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pmoros/sandbox/university/data-mining/data-mining-2023-II/preprocessing/main.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> df_eval_route_package_data['time_to_arrive'] = df_eval_route_package_data.apply(lambda row: get_time_to_reach_stop_from_source(row['RouteID'], row['starting_point'], row['StopID']), axis=1)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pmoros/sandbox/university/data-mining/data-mining-2023-II/preprocessing/main.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> df_eval_route_package_data
#
# /home/pmoros/sandbox/university/data-mining/data-mining-2023-II/preprocessing/main.ipynb Cell 16 line 3
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pmoros/sandbox/university/data-mining/data-mining-2023-II/preprocessing/main.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> def get_time_to_reach_stop_from_source(route, source, stop):
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pmoros/sandbox/university/data-mining/data-mining-2023-II/preprocessing/main.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     return travel_times_dataset[route][source][stop]
#
# File ~/sandbox/university/data-mining/data-mining-2023-II/venv/lib/python3.10/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~/sandbox/university/data-mining/data-mining-2023-II/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'RouteID_00092558-dece-4fb7-8d0d-7d0df3a4864e'
